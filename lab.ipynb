# %%
import pandas as pd
import numpy as np 

opt_1 = pd.read_csv('tests_data/default.csv', sep=",")
opt_2 = pd.read_csv('tests_data/default_O3.csv', sep=",")
opt_3 = pd.read_csv('tests_data/crc.csv', sep=",")
opt_4 = pd.read_csv('tests_data/strcmp.csv', sep=",")
opt_5 = pd.read_csv('tests_data/cycle.csv', sep=",")
opt_6 = pd.read_csv('tests_data/strlen.csv', sep=",")

opt_1_rep = opt_1['rep']
opt_1_time = opt_1['time'] / 300

opt_2_rep = opt_2['rep']
opt_2_time = opt_2['time'] / 300

opt_3_rep = opt_3['rep']
opt_3_time = opt_3['time'] / 300

opt_4_rep = opt_4['rep']
opt_4_time = opt_4['time'] / 300

opt_5_rep = opt_5['rep']
opt_5_time = opt_5['time'] / 300

opt_6_rep = opt_6['rep']
opt_6_time = opt_6['time'] / 300


mean_1 = np.mean(opt_1_time)
mean_2 = np.mean(opt_2_time)
mean_3 = np.mean(opt_3_time)
mean_4 = np.mean(opt_4_time)
mean_5 = np.mean(opt_5_time)
mean_6 = np.mean(opt_6_time)

error_1 = np.std(opt_1_time, ddof=1)
error_2 = np.std(opt_2_time, ddof=1)
error_3 = np.std(opt_3_time, ddof=1)
error_4 = np.std(opt_4_time, ddof=1)
error_5 = np.std(opt_5_time, ddof=1)
error_6 = np.std(opt_6_time, ddof=1)

# %% [markdown]
# $DEFAULT \quad VERSION \quad WITHOUT -O3$

# %%
mean_1, error_1
# Out:
# (55.83673333333333, 2.131037646200509)

# %% [markdown]
# $DEFAULT \quad VERSION \quad WITH -O3$

# %%
mean_2, error_2
# Out:
# (37.88456666666667, 1.308965824429274)

# %% [markdown]
# $CRC32 \quad OPTIMIZATION$

# %%
mean_3, error_3
# Out:
# (31.450833333333335, 0.7672482965581802)

# %% [markdown]
# $STRCMP \quad OPTIMIZATION$

# %%
mean_4, error_4
# Out:
# (30.252225, 0.20612558796974567)

# %% [markdown]
# $CYCLE \quad OPTIMIZATION$

# %%
mean_5, error_5
# Out:
# (23.848599999999998, 0.1813889961836388)

# %% [markdown]
# $STRLEN \quad OPTIMIZATION$

# %%
mean_6, error_6
# Out:
# (23.545074074074076, 0.07909068419959739)
