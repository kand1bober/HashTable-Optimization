# %% [markdown]
# $CRC 32$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('dispersia_1.csv') 

x = data['bucket_num']
y = data['bucket_size']

# -----------------------
dispersia = np.var(y)
mean_val = np.mean(y)
# -----------------------

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.bar(x, y)

bars = plt.bar(
    df["bucket_num"],
    df["bucket_size"],
    width=1,          # Почти перекрывающиеся столбцы
    color='#1f77b4',    # Синий цвет
    label=f'среднее = {mean_val:.3f}\nдисперсия = {dispersia:.3f}'
)

plt.title("Распределение элементов по бакетам в хеш-таблице (CRC32)")
plt.xlabel("Номер бакета")
plt.ylabel("Кол-во элементов в бакете")

plt.ylim(0, 35)
plt.yticks(range(0, 35, 1)) 

plt.grid(
    True,
    color='lightblue',
    linestyle='--',
    alpha=0.6
)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# $MurMurHash$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('dispersia_2.csv') 

x = data['bucket_num']
y = data['bucket_size']

# -----------------------
dispersia = np.var(y)
mean_val = np.mean(y)
# -----------------------

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.bar(x, y)

bars = plt.bar(
    df["bucket_num"],
    df["bucket_size"],
    width=1,          # Почти перекрывающиеся столбцы
    color='#1f77b4',    # Синий цвет
    label=f'среднее = {mean_val:.3f}\nдисперсия = {dispersia:.3f}'
)

plt.title("Распределение элементов по бакетам в хеш-таблице (MurMurHash)")
plt.xlabel("Номер бакета")
plt.ylabel("Кол-во элементов в бакете")

plt.ylim(0, 35)
plt.yticks(range(0, 35, 1)) 

plt.grid(
    True,
    color='lightblue',
    linestyle='--',
    alpha=0.6
)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# $StupidHash$ = $sum$ $of$ $ascii$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('dispersia_3.csv') 

x = data['bucket_num']
y = data['bucket_size']

# -----------------------
dispersia = np.var(y)
mean_val = np.mean(y)
# -----------------------

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.bar(x, y)

bars = plt.bar(
    df["bucket_num"],
    df["bucket_size"],
    width=1,          # Почти перекрывающиеся столбцы
    color='#1f77b4',    # Синий цвет
    label=f'среднее = {mean_val:.3f}\nдисперсия = {dispersia:.3f}'
)

plt.title("Распределение элементов по бакетам в хеш-таблице (Сумма ascii символов слова)")
plt.xlabel("Номер бакета")
plt.ylabel("Кол-во элементов в бакете")

# plt.ylim(0, 35)
# plt.yticks(range(0, 35, 1)) 

plt.grid(
    True,
    color='lightblue',
    linestyle='--',
    alpha=0.6
)

plt.legend()
plt.tight_layout()
plt.show()
